# %%
t = [0.02, 0.05, 0.08, 0.10, 0.15,0.2,0.25, 0.3,0.35,  0.4, 0.5, 0.6, 0.7, 0.8, 1]

# %% [markdown]
# # narrowpassage

# %%
success_att = [0.0, 0.0, 0.09, 0.16, 0.45, 0.56, 0.71, 0.73, 0.79, 0.84, 0.92, 0.96, 0.99, 0.99, 1.0]

# %%
sucess_random = [0.0, 0.0, 0.08, 0.1, 0.27, 0.47,  0.62, 0.73, 0.81, 0.87, 0.94, 0.94, 0.95, 0.99, 1.0]

# %%
succ_att = [0.0, 0.01, 0.17, 0.2, 0.45, 0.68, 0.72, 0.78, 0.86, 0.92, 0.94, 0.96, 0.97, 1.0, 1.0]
succ_ran= [0.0, 0.0, 0.03, 0.13, 0.35, 0.51, 0.58, 0.72, 0.85, 0.92, 0.93, 0.99, 0.99, 1.0, 1.0]
len_att = [0, 3.51, 3.24, 2.75, 2.89,  2.98, 2.98, 2.95, 2.92, 2.85, 2.94, 3.16, 3.01, 2.86, 2.90]
len_ran = [0, 0, 2.88, 3.11, 2.97, 3.19, 3.19, 3.3, 3.19, 3.21, 3.26, 3.14, 3.24, 3.05, 3.16]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t, succ_att)
plt.plot(t, succ_ran)
plt.ylabel('sucess rate')
plt.xlabel('solve time /s')
plt.show()

# %%
plt.plot(t, len_att)
plt.plot(t, len_ran)
plt.ylabel('cost')
plt.xlabel('solve time')
plt.show()

# %% [markdown]
# # minicity case 1

# %%
t=[0.2, 0.5, 0.6, 0.7, 0.8, 0.9, 1, 1.2, 1.4, 1.7, 2]

# %%
succ_att = [0.0, 0.25, 0.34, 0.45, 0.56, 0.57, 0.79, 0.81, 0.84, 0.96, 0.93]
succ_ran= [0.0, 0.14, 0.26, 0.2, 0.26, 0.33, 0.33, 0.5, 0.57, 0.69, 0.7]
len_att = [7.0, 2.07, 1.63, 1.07,  0.69, 0.58, 0.28, 0.26, 0.12, 0.02, 0.05]
len_ran = [5.7, 1.99, 1.75, 1.60, 1.31, 1.31, 1.16, 0.81,  0.61,  0.30, 0.31]

# %%
plt.plot(t, succ_att)
plt.plot(t, succ_ran)
plt.ylabel('sucess rate')
plt.xlabel('solve time /s')
plt.show()

# %%
plt.plot(t, len_att)
plt.plot(t, len_ran)
plt.ylabel('cost')
plt.xlabel('solve time')
plt.show()

# %% [markdown]
# # minicity case 2

# %%
t = [0.2, 0.5, 0.6, 0.7, 0.8, 0.9, 1, 1.2, 1.4, 1.7, 2, 2.3, 2.7, 3, 4]
succ_att = [0.01,    0.27,     0.35,     0.45,      0.51,    0.59,   0.71,               0.83,    0.86,    0.89,   0.95, 0.99, 1.0, 1, 1]
dis_att =     [6.4,     2.19,      1.56,     0.96,     0.77,     0.55,   0.42,              0.19,     0.22,    0.09,   0.04, 0.00, 0, 0, 0]
len_att =    [17.17, 18.18,    18.54,  18.51,     18.39,     18.68,    18.49,    18.43,     18.47,    18.33,   18.4, 18.49, 18.8, 18.34, 18.38]
succ_ran= [0.01,    0.17,      0.14,     0.23,       0.24,     0.43,    0.46,             0.5,        0.62,    0.63,   0.71, 0.81, 0.83, 0.89, 0.97]
dis_ran =   [5.02,     1.89,     2.96,     1.76,    1.49,      0.96,    1.03,               1.01,     0.66,     0.38,   0.414, 0.14, 0.16, 0.15, 0.02]
len_ran =   [17.99,  18.47,   18.67,   18.39,    18.87,      18.7,    18.40,     18.73,     18.54,    18.91,   18.64, 18.78, 18.8, 18.72, 18.38]

# %%
plt.plot(t, succ_att)
plt.plot(t, succ_ran)
plt.ylabel('sucess rate')
plt.xlabel('solve time /s')
plt.show()

# %%
plt.plot(t, len_att)
plt.plot(t, len_ran)
plt.ylabel('cost')
plt.xlabel('solve time')
plt.show()

# %%
plt.plot(t, dis_att)
plt.plot(t, dis_ran)
plt.ylabel('distance to goal')
plt.xlabel('solve time')
plt.show()
